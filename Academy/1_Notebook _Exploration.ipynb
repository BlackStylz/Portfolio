# %% [markdown]
# # Exploration du jeu de données

# %% [markdown]
# ### Ouverture des fichiers

# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

countries = pd.read_csv("./Data/EdStatsCountry.csv")
c_series = pd.read_csv("./Data/EdStatsCountry-Series.csv")
data = pd.read_csv("./Data/EdStatsData.csv")
foot_note = pd.read_csv("./Data/EdStatsFootNote.csv")
series = pd.read_csv("./Data/EdStatsSeries.csv")

# Dimensions des Dataframes

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Exploration EdStatsCountry.csv

# %%
countries.shape #Taille du Dataframe
# Out:
# (241, 32)

# %%
countries.dtypes
# Out:
# Country Code                                          object
# Short Name                                            object
# Table Name                                            object
# Long Name                                             object
# 2-alpha code                                          object
# Currency Unit                                         object
# Special Notes                                         object
# Region                                                object
# Income Group                                          object
# WB-2 code                                             object
# National accounts base year                           object
# National accounts reference year                     float64
# SNA price valuation                                   object
# Lending category                                      object
# Other groups                                          object
# ...

# %%
countries.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           3
# Currency Unit                                         26
# Special Notes                                         96
# Region                                                27
# Income Group                                          27
# WB-2 code                                              1
# National accounts base year                           36
# National accounts reference year                     209
# SNA price valuation                                   44
# Lending category                                      97
# Other groups                                         183
# System of National Accounts                           26
# ...

# %%
countries.loc[countries.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Country Code, Short Name, Table Name, Long Name, 2-alpha code, Currency Unit, Special Notes, Region, Income Group, WB-2 code, National accounts base year, National accounts reference year, SNA price valuation, Lending category, Other groups, System of National Accounts, Alternative conversion factor, PPP survey year, Balance of Payments Manual in use, External debt Reporting status, System of trade, Government Accounting concept, IMF data dissemination standard, Latest population census, Latest household survey, Source of most recent Income and expenditure data, Vital registration complete, Latest agricultural census, Latest industrial data, Latest trade data, Latest water withdrawal data, Unnamed: 31]
# Index: []

# %%
countries
# Out:
#     Country Code                                      Short Name  \
# 0            ABW                                           Aruba
# 1            AFG                                     Afghanistan
# 2            AGO                                          Angola
# 3            ALB                                         Albania
# 4            AND                                         Andorra
# 5            ARB                                      Arab World
# 6            ARE                            United Arab Emirates
# 7            ARG                                       Argentina
# 8            ARM                                         Armenia
# 9            ASM                                  American Samoa
# 10           ATG                             Antigua and Barbuda
# 11           AUS                                       Australia
# 12           AUT                                         Austria
# ...

# %%
msno.matrix(countries)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exploration EdStatsCountry-Series.csv

# %%
c_series.shape #Taille du Dataframe
# Out:
# (613, 4)

# %%
c_series.dtypes
# Out:
# CountryCode     object
# SeriesCode      object
# DESCRIPTION     object
# Unnamed: 3     float64
# dtype: object

# %%
c_series.isnull().sum()
# Out:
# CountryCode      0
# SeriesCode       0
# DESCRIPTION      0
# Unnamed: 3     613
# dtype: int64

# %%
c_series.loc[c_series.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [CountryCode, SeriesCode, DESCRIPTION, Unnamed: 3]
# Index: []

# %%
msno.matrix(c_series)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exploration EdStatsSeries.csv

# %%
series.shape #Taille du Dataframe
# Out:
# (3665, 21)

# %%
series.dtypes
# Out:
# Series Code                             object
# Topic                                   object
# Indicator Name                          object
# Short definition                        object
# Long definition                         object
# Unit of measure                        float64
# Periodicity                             object
# Base Period                             object
# Other notes                             object
# Aggregation method                      object
# Limitations and exceptions              object
# Notes from original source             float64
# General comments                        object
# Source                                  object
# Statistical concept and methodology     object
# Development relevance                   object
# Related source links                    object
# Other web links                        float64
# Related indicators                     float64
# License Type                           float64
# ...

# %%
series.isnull().sum()
# Out:
# Series Code                               0
# Topic                                     0
# Indicator Name                            0
# Short definition                       1509
# Long definition                           0
# Unit of measure                        3665
# Periodicity                            3566
# Base Period                            3351
# Other notes                            3113
# Aggregation method                     3618
# Limitations and exceptions             3651
# Notes from original source             3665
# General comments                       3651
# Source                                    0
# Statistical concept and methodology    3642
# Development relevance                  3662
# Related source links                   3450
# Other web links                        3665
# Related indicators                     3665
# License Type                           3665
# Unnamed: 20                            3665
# dtype: int64

# %%
series.loc[series.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Series Code, Topic, Indicator Name, Short definition, Long definition, Unit of measure, Periodicity, Base Period, Other notes, Aggregation method, Limitations and exceptions, Notes from original source, General comments, Source, Statistical concept and methodology, Development relevance, Related source links, Other web links, Related indicators, License Type, Unnamed: 20]
# Index: []

# %%
series
# Out:
#                       Series Code         Topic  \
# 0             BAR.NOED.1519.FE.ZS    Attainment
# 1                BAR.NOED.1519.ZS    Attainment
# 2             BAR.NOED.15UP.FE.ZS    Attainment
# 3                BAR.NOED.15UP.ZS    Attainment
# 4             BAR.NOED.2024.FE.ZS    Attainment
# ...                           ...           ...
# 3660    UIS.XUNIT.USCONST.3.FSGOV  Expenditures
# 3661    UIS.XUNIT.USCONST.4.FSGOV  Expenditures
# 3662   UIS.XUNIT.USCONST.56.FSGOV  Expenditures
# 3663  XGDP.23.FSGOV.FDINSTADM.FFD  Expenditures
# 3664  XGDP.56.FSGOV.FDINSTADM.FFD  Expenditures
#
#                                          Indicator Name  \
# 0     Barro-Lee: Percentage of female population age...
# 1     Barro-Lee: Percentage of population age 15-19 ...
# 2     Barro-Lee: Percentage of female population age...
# 3     Barro-Lee: Percentage of population age 15+ wi...
# 4     Barro-Lee: Percentage of female population age...
# ...

# %%
series["Topic"].value_counts()
# Out:
# Learning Outcomes                                                                               1046
# Attainment                                                                                       733
# Education Equality                                                                               426
# Secondary                                                                                        256
# Primary                                                                                          248
# Population                                                                                       213
# Tertiary                                                                                         158
# Teachers                                                                                         137
# Expenditures                                                                                      93
# ...

# %%
series["Topic"].value_counts().shape #Nombre de sujets (Indicateurs)
# Out:
# (37,)

# %%
msno.matrix(series)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exploration EdStatsFootNote.csv

# %%
foot_note.shape #Taille du Dataframe
# Out:
# (643638, 5)

# %%
foot_note.dtypes
# Out:
# CountryCode     object
# SeriesCode      object
# Year            object
# DESCRIPTION     object
# Unnamed: 4     float64
# dtype: object

# %%
foot_note.isnull().sum()
# Out:
# CountryCode         0
# SeriesCode          0
# Year                0
# DESCRIPTION         0
# Unnamed: 4     643638
# dtype: int64

# %%
foot_note.loc[foot_note.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [CountryCode, SeriesCode, Year, DESCRIPTION, Unnamed: 4]
# Index: []

# %%
foot_note
# Out:
#        CountryCode      SeriesCode    Year  \
# 0              ABW  SE.PRE.ENRL.FE  YR2001
# 1              ABW  SE.TER.TCHR.FE  YR2005
# 2              ABW  SE.PRE.TCHR.FE  YR2000
# 3              ABW  SE.SEC.ENRL.GC  YR2004
# 4              ABW     SE.PRE.TCHR  YR2006
# ...            ...             ...     ...
# 643633         ZWE     SH.DYN.MORT  YR2007
# 643634         ZWE     SH.DYN.MORT  YR2014
# 643635         ZWE     SH.DYN.MORT  YR2015
# 643636         ZWE     SH.DYN.MORT  YR2017
# 643637         ZWE     SP.POP.GROW  YR2017
#
#                                    DESCRIPTION  Unnamed: 4
# 0                          Country estimation.         NaN
# 1                          Country estimation.         NaN
# 2                          Country estimation.         NaN
# 3                          Country estimation.         NaN
# 4                          Country estimation.         NaN
# ...                                        ...         ...
# ...

# %%
foot_note["CountryCode"].value_counts().shape #Nombre de pays
# Out:
# (239,)

# %%
foot_note["CountryCode"].value_counts()
# Out:
# LIC    7320
# CYP    7183
# LDC    6481
# SSA    6389
# SSF    6336
# HPC    6237
# LAC    6116
# MIC    5862
# LMY    5839
# LCN    5779
# WLD    5706
# ARB    5595
# AZE    5451
# LMC    5390
# ECA    5350
# MDA    5095
# HKG    4785
# UKR    4719
# HIC    4598
# LBN    4597
# MEA    4591
# MNA    4532
# MAR    4530
# ECS    4487
# SAS    4470
# MUS    4104
# UMC    4085
# LSO    4016
# EGY    3992
# ESP    3989
# KWT    3955
# BWA    3927
# AUS    3810
# QAT    3753
# FIN    3723
# NOR    3697
# SRB    3688
# COL    3645
# EUU    3628
# MLT    3615
# OED    3614
# EMU    3601
# GHA    3550
# EAS    3533
# SLV    3516
# TZA    3514
# TTO    3504
# KOR    3489
# CUB    3442
# TUN    3435
# NLD    3433
# BRA    3431
# BEN    3410
# HUN    3363
# ITA    3360
# MYS    3354
# MEX    3348
# EAP    3308
# PSE    3298
# TUR    3295
# GBR    3279
# NER    3267
# IRN    3260
# CHN    3257
# BDI    3255
# AUT    3251
# TGO    3249
# BGR    3238
# JPN    3236
# CZE    3194
# DNK    3189
# ...

# %%
foot_note["Year"].value_counts()
# Out:
# YR2004    27128
# YR2005    25992
# YR2002    25687
# YR2003    25683
# YR2000    25093
# YR2001    25047
# YR2008    25018
# YR1999    24938
# YR2007    24263
# YR2006    23394
# YR2009    22965
# YR2010    22598
# YR2011    17760
# YR1998    14916
# YR2012    13890
# YR2013    13405
# YR1994    11448
# YR2014    11378
# YR1992    11309
# YR1996    11197
# YR1995    11194
# YR1997    11167
# YR1991    11129
# YR1993    11093
# YR1990    10616
# YR1986     9743
# YR1985     9653
# YR1989     9517
# YR1981     9465
# YR1984     9386
# YR1988     9382
# YR1987     9357
# YR1983     9227
# YR1982     9014
# YR1980     8950
# YR1979     8742
# YR1976     8729
# YR1972     8661
# YR1975     8627
# YR1977     8593
# YR1978     8585
# YR1973     8571
# YR1974     8512
# YR1971     8507
# YR2015     6348
# YR1970     5374
# YR2016      819
# YR2017      558
# YR2050      144
# YR2040      144
# YR2045      144
# YR2035      144
# YR2025      140
# YR2030      140
# YR2020      140
# ...

# %%
foot_note["Year"].value_counts().shape # Nombre d'années
# Out:
# (56,)

# %%
foot_note["SeriesCode"].value_counts().shape
# Out:
# (1558,)

# %%
msno.matrix(foot_note)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exploration de EdStatsData.csv

# %%
data.shape #Taille du Dataframe
# Out:
# (886930, 70)

# %%
data.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
# 1986              float64
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# ...

# %%
data.isnull().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
# 1971              851393
# 1972              851311
# 1973              851385
# 1974              851200
# 1975              799624
# 1976              849447
# 1977              849356
# 1978              849354
# 1979              850121
# 1980              797808
# 1981              848153
# 1982              849419
# 1983              848470
# 1984              848324
# 1985              796634
# 1986              847558
# 1987              848289
# 1988              848378
# 1989              849390
# 1990              762525
# 1991              812493
# 1992              811387
# 1993              811137
# 1994              809468
# 1995              755569
# 1996              810123
# 1997              813477
# 1998              802016
# 1999              768091
# 2000              710254
# 2001              763421
# 2002              762725
# ...

# %%
data.loc[data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2020, 2025, 2030, 2035, 2040, 2045, 2050, 2055, 2060, 2065, 2070, 2075, 2080, 2085, 2090, 2095, 2100, Unnamed: 69]
# Index: []

# %%
data
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# 3       Adjusted net enrolment rate, lower secondary, ...
# 4       Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# ...

# %%
data["Country Name"].value_counts().shape #Nombre de pays différents
# Out:
# (242,)

# %%
data["Indicator Code"].value_counts().shape #Nombre d'indicateur différents
# Out:
# (3665,)

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Filtrage des données

# %% [markdown]
# ### Filtrage des pays

# %%
p = pd.read_csv("./Data/Pays.csv") #Liste des pays reconnu par l'ONU
pays = p["Name"].tolist()

# %%
un_countries = countries.loc[countries["Short Name"].isin(pays)] # Filtrage grace à la liste
un_countries.shape
# Out:
# (191, 32)

# %% [markdown]
# Copie de data

# %%
data_b = data.copy()
data_b.shape
# Out:
# (886930, 70)

# %% [markdown]
# Filtrage des pays sur la copie du fichier EdStatsData

# %%
data_b = data_b.loc[data_b['Country Code'].isin(un_countries['Country Code'])]
data_b.shape
# Out:
# (700015, 70)

# %% [markdown]
# ### Filtrage des indicateurs

# %% [markdown]
# Création de la liste des indicateurs choisis historiques et pour la projection

# %%
ind_hist = ["SP.POP.TOTL",
"SP.POP.1524.TO.UN",
"NY.GDP.PCAP.CD",
"NY.GNP.PCAP.CD",
"IT.NET.USER.P2", 
"UIS.GER.4", 
"UIS.CR.3",         
"SE.SEC.ENRR.UP",        
"UIS.SCHBSP.3.WCOMPUT",         
]

ind_prj = ["PRJ.ATT.15UP.4.MF",
"PRJ.MYS.15UP.MF",
"PRJ.ATT.15UP.3.MF"]

# %%
data_fil = data_b.loc[data_b["Indicator Code"].isin(ind_hist) | data_b["Indicator Code"].isin(ind_prj)]

# %%
data_fil.shape
# Out:
# (1910, 70)

# %% [markdown]
# Retirer les années avant 2005

# %%
years=[]
for n in range(1970, 2005):
    years.append(str(n))
    
data_fil.drop(years,axis=1,inplace=True)

data_fil.shape
# Out:
# C:\Users\Steph\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (1910, 35)

# %% [markdown]
# ##### Dataframme données historiques

# %%
df_hist = data_fil.loc[data_fil["Indicator Code"].isin(ind_hist)]
print(df_hist.shape)
msno.matrix(df_hist)
# Out:
# (1337, 35)
# <AxesSubplot:>

# %% [markdown]
# Supprimer les colonnes avec 10% ou plus de valeurs manquantes

# %%
df_hist.dropna(thresh=(0.1*df_hist.shape[0]), axis=1, inplace =True)
msno.matrix(df_hist)
# Out:
# <ipython-input-50-961e17da2212>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist.dropna(thresh=(0.1*df_hist.shape[0]), axis=1, inplace =True)
# <AxesSubplot:>

# %% [markdown]
# Créer une table pivot

# %%
country_bis = un_countries[['Country Code','Region']] # Extraire les régions

# %%
hist = df_hist.pivot_table(values='2016',index=['Country Code'] , columns=['Indicator Code'])
hist = pd.merge(hist ,country_bis, on="Country Code") #associer les régions et les pays
hist.dropna(thresh =(0.5*hist.shape[0]), axis=1, inplace=True)
hist.dropna(inplace=True)
msno.matrix(hist)#.dropna(thresh=6, axis=0))
# Out:
# <AxesSubplot:>

# %%
hist.describe()
# Out:
#        IT.NET.USER.P2  NY.GDP.PCAP.CD  NY.GNP.PCAP.CD   SP.POP.TOTL
# count      171.000000      171.000000      171.000000  1.710000e+02
# mean        49.508830    12384.595078    12421.052632  4.233556e+07
# std         27.490151    17338.777714    16963.448597  1.504745e+08
# min          3.761414      285.727442      280.000000  1.109700e+04
# 25%         25.036652     1804.896644     1990.000000  2.364986e+06
# 50%         51.349874     4878.575791     4980.000000  9.269612e+06
# 75%         74.063775    14670.928289    14660.000000  3.148055e+07
# max         98.240016   100573.139978    82440.000000  1.378665e+09

# %%
#sns.boxplot(data=hist.groupby("Region").mean(), y="Region", x="NY.GDP.PCAP.CD")
plt.figure(figsize= (20,10))
plt.subplot(2,2,1)
sns.boxplot(
    data=hist, x="NY.GDP.PCAP.CD", y="Region",
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.4, .6, .8, .5)},
    medianprops={"color": "coral"},
)
plt.xlabel("PIB par habitant ($)")

plt.subplot(2,2,2)
sns.boxplot(
    data=hist, x="NY.GNP.PCAP.CD", y="Region",
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.4, .6, .8, .5)},
    medianprops={"color": "coral"},
)
plt.xlabel("PNB par habitant ($)")

plt.subplot(2,2,3)
sns.barplot(
    data=hist, x="SP.POP.TOTL", y="Region",
    linewidth=3, edgecolor=".5", facecolor=(.4, .6, .8, .5),
)
plt.xlabel("Population")

plt.subplot(2,2,4)
sns.boxplot(
    data=hist, x="IT.NET.USER.P2", y="Region",
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.4, .6, .8, .5)},
    medianprops={"color": "coral"},
)
plt.xlabel("Utilisateur d'internet (%)")

plt.subplots_adjust(hspace=0.45,wspace=0.40)

plt.show()

# %% [markdown]
# ##### Dataframme données pour projection

# %%
df_prj = data_fil.loc[data_fil["Indicator Code"].isin(ind_prj)]
print(df_prj.shape)
msno.matrix(df_prj)
# Out:
# (573, 35)
# <AxesSubplot:>

# %%
df_prj.dropna(thresh=(0.1*df_prj.shape[0]), axis=1, inplace =True)
msno.matrix(df_prj)
# Out:
# <ipython-input-56-d56e13257a36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prj.dropna(thresh=(0.1*df_prj.shape[0]), axis=1, inplace =True)
# <AxesSubplot:>

# %%
df_prj =pd.merge(country_bis, df_prj, on="Country Code") #associer les régions et les pays

# %%
df_prj.dropna(thresh=(df_prj.shape[1]-5), axis=0, inplace=True)
msno.matrix(df_prj)
# Out:
# <AxesSubplot:>
